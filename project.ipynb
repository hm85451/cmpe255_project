# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb 

cols = ['x.state', #state
        'sexvar', #sex
        'physhlth', # number of days physical health is not good(per month)
        'menthlth', # number of days mental health is not good(per month)
        'exerany2', # Exercise in Past 30 Days   
        'cvdinfr4', # Ever Diagnosed with Heart Attack
        'cvdcrhd4', #Ever Diagnosed with Angina or Coronary Heart Disease
        'cvdstrk3', #Ever Diagnosed with a Stroke
        'asthma3', #Ever Told Had Asthma
        'asthnow', #Still Have Asthma
        'addepev3', #(Ever told) you had a depressive disorder
        'chckdny2', #Ever told you have kidney disease?
        'havarth4', #Told Had Arthritis
        'diabete4', #(Ever told) you had diabetes
        'educa', # eudcation level
        'income3', # income level 
        'weight2', # reported weight in pounds
        'height3', # reported height in feet and inches 
        'lcsnumcg', # how many cigarettes do you smoke each day?
        'avedrnk3', # Avg alcoholic drinks per day in past 30
        'lsatisfy', # satisfaction with life
        'emtsuprt', # How often get emotional support needed
        'sdhisolt', #How often do you feel socially isolated from others?
        'mscode', # Metropolitan Status Code
        'x.age80', # Imputed Age value collapsed above 80
        'x.bmi5', # Computed body mass index 
        'sleptim1'# sleep time       
       ]
df = pd.read_csv("brfss2022.csv")
df = df[cols]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 27 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   x.state   445132 non-null  int64
#  1   sexvar    445132 non-null  int64
#  2   physhlth  445127 non-null  float64
#  3   menthlth  445129 non-null  float64
#  4   exerany2  445130 non-null  float64
#  5   cvdinfr4  445128 non-null  float64
#  6   cvdcrhd4  445130 non-null  float64
#  7   cvdstrk3  445130 non-null  float64
#  8   asthma3   445130 non-null  float64
#  9   asthnow   66694 non-null   float64
#  10  addepev3  445125 non-null  float64
#  11  chckdny2  445130 non-null  float64
#  12  havarth4  445129 non-null  float64
#  13  diabete4  445129 non-null  float64
#  14  educa     445127 non-null  float64
#  15  income3   432200 non-null  float64
#  16  weight2   429231 non-null  float64
#  17  height3   428077 non-null  float64
#  18  lcsnumcg  156140 non-null  float64
#  19  avedrnk3  210363 non-null  float64
#  20  lsatisfy  254488 non-null  float64
#  21  emtsuprt  254141 non-null  float64
#  22  sdhisolt  253790 non-null  float64
#  23  mscode    93886 non-null   float64
#  24  x.age80   445132 non-null  int64
#  25  x.bmi5    396326 non-null  float64
#  26  sleptim1  445129 non-null  float64
# dtypes: float64(24), int64(3)
# memory usage: 91.7 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 27 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   x.state   445132 non-null  int64
#  1   sexvar    445132 non-null  int64
#  2   physhlth  445127 non-null  float64
#  3   menthlth  445129 non-null  float64
#  4   exerany2  445130 non-null  float64
#  5   cvdinfr4  445128 non-null  float64
#  6   cvdcrhd4  445130 non-null  float64
#  7   cvdstrk3  445130 non-null  float64
#  8   asthma3   445130 non-null  float64
#  9   asthnow   66694 non-null   float64
#  10  addepev3  445125 non-null  float64
#  11  chckdny2  445130 non-null  float64
#  12  havarth4  445129 non-null  float64
#  13  diabete4  445129 non-null  float64
#  14  educa     445127 non-null  float64
#  15  income3   432200 non-null  float64
#  16  weight2   429231 non-null  float64
#  17  height3   428077 non-null  float64
#  18  lcsnumcg  156140 non-null  float64
#  19  avedrnk3  210363 non-null  float64
#  20  lsatisfy  254488 non-null  float64
#  21  emtsuprt  254141 non-null  float64
#  22  sdhisolt  253790 non-null  float64
#  23  mscode    93886 non-null   float64
#  24  x.age80   445132 non-null  int64
#  25  x.bmi5    396326 non-null  float64
#  26  sleptim1  445129 non-null  float64
# dtypes: float64(24), int64(3)
# memory usage: 91.7 MB

# %%
df.head(10)
# Out:
#    x.state  sexvar  physhlth  menthlth  exerany2  cvdinfr4  cvdcrhd4  \
# 0        1       2      88.0      88.0       2.0       2.0       2.0
# 1        1       2      88.0      88.0       2.0       2.0       2.0
# 2        1       2       2.0       3.0       1.0       2.0       2.0
# 3        1       2      88.0      88.0       1.0       2.0       2.0
# 4        1       2       2.0      88.0       1.0       2.0       2.0
# 5        1       1       1.0      88.0       2.0       1.0       2.0
# 6        1       2      88.0      88.0       1.0       2.0       2.0
# 7        1       2      88.0      88.0       2.0       2.0       2.0
# 8        1       2      88.0      88.0       1.0       2.0       2.0
# 9        1       2       1.0      88.0       1.0       2.0       2.0
#
#    cvdstrk3  asthma3  asthnow  ...  height3  lcsnumcg  avedrnk3  lsatisfy  \
# 0       2.0      2.0      NaN  ...   9999.0       NaN       NaN       1.0
# 1       2.0      2.0      NaN  ...    503.0       NaN       NaN       1.0
# 2       2.0      2.0      NaN  ...    502.0       NaN       NaN       2.0
# 3       2.0      1.0      1.0  ...    505.0       2.0       NaN       1.0
# 4       2.0      2.0      NaN  ...    502.0       NaN       2.0       1.0
# 5       1.0      2.0      NaN  ...    511.0       NaN       NaN       2.0
# 6       2.0      2.0      NaN  ...    505.0      35.0       2.0       1.0
# 7       2.0      2.0      NaN  ...    504.0       NaN       NaN       1.0
# 8       2.0      2.0      NaN  ...    507.0       5.0       NaN       1.0
# 9       2.0      2.0      NaN  ...    506.0       NaN       1.0       1.0
#
#    emtsuprt  sdhisolt  mscode  x.age80  x.bmi5  sleptim1
# 0       1.0       5.0     2.0       80     NaN       8.0
# 1       1.0       5.0     5.0       80  2657.0       6.0
# 2       2.0       3.0     2.0       56  2561.0       5.0
# 3       1.0       3.0     1.0       73  2330.0       7.0
# 4       1.0       5.0     1.0       43  2177.0       9.0
# 5       2.0       5.0     2.0       80  2608.0       7.0
# 6       1.0       4.0     1.0       80  2296.0       7.0
# 7       1.0       5.0     1.0       80  2781.0       8.0
# 8       1.0       4.0     1.0       78     NaN       6.0
# 9       1.0       4.0     1.0       72  2905.0       7.0
#
# [10 rows x 27 columns]

# %%
cols = ['x.state', #state
        'sexvar', #sex
        'physhlth', # number of days physical health is not good(per month)
        'menthlth', # number of days mental health is not good(per month)
        'exerany2', # Exercise in Past 30 Days   
        'cvdinfr4', # Ever Diagnosed with Heart Attack
        'cvdcrhd4', #Ever Diagnosed with Angina or Coronary Heart Disease
        'cvdstrk3', #Ever Diagnosed with a Stroke
        'asthma3', #Ever Told Had Asthma
        'asthnow', #Still Have Asthma
        'addepev3', #(Ever told) you had a depressive disorder
        'chckdny2', #Ever told you have kidney disease?
        'havarth4', #Told Had Arthritis
        'diabete4', #(Ever told) you had diabetes
        'educa', # eudcation level
        'income3', # income level 
        'weight2', # reported weight in pounds
        'height3', # reported height in feet and inches 
        'lcsnumcg', # how many cigarettes do you smoke each day?
        'avedrnk3', # Avg alcoholic drinks per day in past 30
        'lsatisfy', # satisfaction with life
        'emtsuprt', # How often get emotional support needed
        'sdhisolt', #How often do you feel socially isolated from others?
        'mscode', # Metropolitan Status Code
        'x.age80', # Imputed Age value collapsed above 80
        'x.bmi5', # Computed body mass index 
        'sleptim1'# sleep time       
       ]

#clean up physhlth
df.loc[df['physhlth']==88, 'physhlth'] = 0
df.loc[df['physhlth']==77, 'physhlth'] = np.nan
df.loc[df['physhlth']==99, 'physhlth'] = np.nan

#clean up menthlth
df.loc[df['menthlth']==88, 'menthlth'] = 0
df.loc[df['menthlth']==77, 'menthlth'] = np.nan
df.loc[df['menthlth']==99, 'menthlth'] = np.nan

#binary answer: yes = 1, no = 2
#clean up exerany2
df.loc[df['exerany2']==7, 'exerany2'] = np.nan
df.loc[df['exerany2']==9, 'exerany2'] = np.nan

#clean up cvdinfr4
df.loc[df['cvdinfr4']==7, 'cvdinfr4'] = np.nan
df.loc[df['cvdinfr4']==9, 'cvdinfr4'] = np.nan

#clean up cvdcrhd4
df.loc[df['cvdcrhd4']==7, 'cvdcrhd4'] = np.nan
df.loc[df['cvdcrhd4']==9, 'cvdcrhd4'] = np.nan

#clean up cvdstrk3
df.loc[df['cvdstrk3']==7, 'cvdstrk3'] = np.nan
df.loc[df['cvdstrk3']==9, 'cvdstrk3'] = np.nan

#clean up asthma3
df.loc[df['asthma3']==7, 'asthma3'] = np.nan
df.loc[df['asthma3']==9, 'asthma3'] = np.nan

#clean up asthnow
df.loc[df['asthnow']==7, 'asthnow'] = np.nan
df.loc[df['asthnow']==9, 'asthnow'] = np.nan

#clean up addepev3
df.loc[df['addepev3']==7, 'addepev3'] = np.nan
df.loc[df['addepev3']==9, 'addepev3'] = np.nan

#clean up chckdny2
df.loc[df['chckdny2']==7, 'chckdny2'] = np.nan
df.loc[df['chckdny2']==9, 'chckdny2'] = np.nan

#clean up havarth4
df.loc[df['havarth4']==7, 'havarth4'] = np.nan
df.loc[df['havarth4']==9, 'havarth4'] = np.nan

#clean up diabete4
df.loc[df['diabete4']==2, 'diabete4'] = 1
df.loc[df['diabete4']==3, 'diabete4'] = 2
df.loc[df['diabete4']==4, 'diabete4'] = 2
df.loc[df['diabete4']==7, 'diabete4'] = np.nan
df.loc[df['diabete4']==9, 'diabete4'] = np.nan

#clean up educa
df.loc[df['educa']==9, 'educa'] = np.nan

#clean up income3
df.loc[df['income3']==77, 'income3'] = np.nan
df.loc[df['income3']==99, 'income3'] = np.nan

#clean up weight2 -need unit converting
df.loc[df['weight2']==9999, 'weight2'] = np.nan


#clean up height3 -need unit converting
df.loc[df['height3']==9999, 'height3'] = np.nan

#clean up lcsnumcg
df.loc[df['lcsnumcg']==777, 'lcsnumcg'] = np.nan
df.loc[df['lcsnumcg']==999, 'lcsnumcg'] = np.nan

#clean up avedrnk3
df.loc[df['avedrnk3']==88, 'avedrnk3'] = 0
df.loc[df['avedrnk3']==77, 'avedrnk3'] = np.nan
df.loc[df['avedrnk3']==99, 'avedrnk3'] = np.nan

#clean up lsatisfy
df.loc[df['lsatisfy']==7, 'lsatisfy'] = np.nan
df.loc[df['lsatisfy']==9, 'lsatisfy'] = np.nan

#clean up mscode

#clean up x.age80

#clean up x.bmi5

#clean up sleptim1
df.loc[df['sleptim1']==77, 'sleptim1'] = np.nan
df.loc[df['sleptim1']==99, 'sleptim1'] = np.nan

#removing sleep time outliers
df[df['sleptim1']>16] = np.nan
df[df['sleptim1']<3] = np.nan

#remove entries whith sleep 

# df['underslpt'] = [np.nan]*len(df['sleptim1'])
# df['overslpt'] = [np.nan]*len(df['sleptim1'])
df['slptscore'] = [np.nan]*len(df['sleptim1'])

# for ind, val in df['sleptim1'].items():
#     if val <= 10:
#         df.at[ind, 'underslpt'] = val
#     else:
#         df.at[ind, 'overslpt'] = val

for ind, val in df['sleptim1'].items():
    if val <= 6:
        df.at[ind, 'slptscore'] = val
    elif (val > 6 and val <= 9):
        df.at[ind, 'slptscore'] = 7
    elif (val >= 10 and val < 16):
        df.at[ind, 'slptscore'] = 16 - val


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 28 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   x.state    441982 non-null  float64
#  1   sexvar     441982 non-null  float64
#  2   physhlth   431168 non-null  float64
#  3   menthlth   433026 non-null  float64
#  4   exerany2   440906 non-null  float64
#  5   cvdinfr4   439007 non-null  float64
#  6   cvdcrhd4   437659 non-null  float64
#  7   cvdstrk3   440461 non-null  float64
#  8   asthma3    440240 non-null  float64
#  9   asthnow    64009 non-null   float64
#  10  addepev3   439222 non-null  float64
#  11  chckdny2   440083 non-null  float64
#  12  havarth4   439378 non-null  float64
#  13  diabete4   440911 non-null  float64
#  14  educa      439638 non-null  float64
#  15  income3    346763 non-null  float64
#  16  weight2    408248 non-null  float64
#  17  height3    417812 non-null  float64
#  18  lcsnumcg   149123 non-null  float64
#  19  avedrnk3   206685 non-null  float64
#  20  lsatisfy   249946 non-null  float64
#  21  emtsuprt   252517 non-null  float64
#  22  sdhisolt   252168 non-null  float64
#  23  mscode     93269 non-null   float64
#  24  x.age80    441982 non-null  float64
#  25  x.bmi5     393697 non-null  float64
#  26  sleptim1   436529 non-null  float64
#  27  slptscore  436200 non-null  float64
# dtypes: float64(28)
# memory usage: 95.1 MB

# %%
#cols = ['x.state', 'sexvar', 'physhlth', 'menthlth', 'exerany2', 'educa', 'income3', 'weight2', 'height3', 'lcsnumcg', 'avedrnk3', 'lsatisfy', 'mscode', 'x.age80', 'x.bmi5', 'sleptim1']
correlation_coefficients = {}
for col in cols:
    correlation_coefficients[col] = df[col].corr(df['sleptim1'])
        
print(correlation_coefficients)

correlation_coefficients = {}
for col in cols:
    correlation_coefficients[col] = df[col].corr(df['slptscore'])
        
print(correlation_coefficients)
# Out:
# {'x.state': 0.00015134576099508793, 'sexvar': 0.017243534042773154, 'physhlth': -0.059864695404117485, 'menthlth': -0.13866343879366522, 'exerany2': -0.0062327292319896465, 'cvdinfr4': -0.006756846439284703, 'cvdcrhd4': -0.010752949665224108, 'cvdstrk3': -0.012105297003495741, 'asthma3': 0.05104978699524659, 'asthnow': 0.018134128913820814, 'addepev3': 0.05509755333925537, 'chckdny2': -0.007295086411173122, 'havarth4': 0.016509193234262795, 'diabete4': -0.004849983674613582, 'educa': 0.01873802788194244, 'income3': 0.005373748572585935, 'weight2': -0.0008236517364675542, 'height3': 0.018206922382907966, 'lcsnumcg': 0.009560817723328698, 'avedrnk3': -0.05344315489622949, 'lsatisfy': -0.11382192131781897, 'emtsuprt': -0.08857797033081814, 'sdhisolt': 0.08544135955217808, 'mscode': 0.010662092610210797, 'x.age80': 0.12057155216579404, 'x.bmi5': -0.05844178440660896, 'sleptim1': 1.0}
# {'x.state': 0.0035038302283360444, 'sexvar': -0.0015752016196384948, 'physhlth': -0.20048723925595635, 'menthlth': -0.23751215914026444, 'exerany2': -0.12899526098780664, 'cvdinfr4': 0.057611914900049625, 'cvdcrhd4': 0.04135826102130854, 'cvdstrk3': 0.0585209866009564, 'asthma3': 0.08386491825489231, 'asthnow': 0.059576091061545676, 'addepev3': 0.1420690077790094, 'chckdny2': 0.050512642687447665, 'havarth4': 0.0831613043623639, 'diabete4': 0.06485437954058017, 'educa': 0.12439717394250292, 'income3': 0.1580053835806012, 'weight2': -0.011372618205098719, 'height3': 0.007971711691314817, 'lcsnumcg': -0.031217233612705647, 'avedrnk3': -0.09709328603506738, 'lsatisfy': -0.19230605304209028, 'emtsuprt': -0.14086402824411545, 'sdhisolt': 0.1504433192248225, 'mscode': -0.001926980967799356, 'x.age80': 0.056569494829106566, 'x.bmi5': -0.0891262281774677, 'sleptim1': 0.5453466009027226}

# %%
bin_range = (1,12)
df.hist(column = ["sleptim1"], bins = 12, range = bin_range)
# Out:
# array([[<Axes: title={'center': 'sleptim1'}>]], dtype=object)

# %%
groupbyState = df.groupby(df['x.state'], as_index=False)['sleptim1'].mean()
print(groupbyState)
print(groupbyState['sleptim1'].max())
print(groupbyState['sleptim1'].min())
# Out:
#     x.state  sleptim1
# 0       1.0  7.012514
# 1       2.0  7.072325
# 2       4.0  7.102185
# 3       5.0  7.058585
# 4       6.0  7.025521
# 5       8.0  7.087503
# 6       9.0  6.986461
# 7      10.0  7.026067
# 8      11.0  7.079481
# 9      12.0  7.070206
# 10     13.0  7.046813
# 11     15.0  6.832398
# 12     16.0  7.086207
# 13     17.0  6.957372
# 14     18.0  6.990042
# 15     19.0  7.083164
# 16     20.0  7.052378
# 17     21.0  6.871436
# 18     22.0  7.028827
# 19     23.0  7.092850
# 20     24.0  7.010224
# 21     25.0  7.021415
# 22     26.0  7.054139
# 23     27.0  7.159599
# 24     28.0  6.998310
# 25     29.0  7.004286
# 26     30.0  7.177762
# 27     31.0  7.172778
# 28     32.0  7.003501
# 29     33.0  7.135147
# 30     34.0  6.936707
# 31     35.0  7.146170
# 32     36.0  6.925409
# 33     37.0  7.019492
# 34     38.0  7.124207
# 35     39.0  6.961124
# 36     40.0  7.017841
# 37     41.0  7.124425
# 38     42.0  6.879483
# 39     44.0  7.002243
# 40     45.0  7.102354
# 41     46.0  7.151897
# 42     47.0  6.982477
# 43     48.0  7.014157
# 44     49.0  7.034262
# 45     50.0  7.147641
# 46     51.0  7.061272
# 47     53.0  7.122061
# 48     54.0  6.901504
# 49     55.0  7.094593
# 50     56.0  7.187561
# 51     66.0  6.632122
# 52     72.0  6.905653
# 53     78.0  6.992847
# 7.1875612144955925
# 6.632122027815163

# %%
c6= df[df['sleptim1']==6]
c7= df[df['sleptim1']==7]
c8= df[df['sleptim1']==8]
c_min = df[(df.sleptim1!=8) & (df.sleptim1!=7) & (df.sleptim1!=6)]
df_6 = c6.sample(35000)
df_7 = c7.sample(35000)
df_8 = c8.sample(35000)
undersampled_df = pd.concat([df_6,df_7,df_8, c_min],axis=0)

# %%
bin_range = (1,12)
undersampled_df.hist(column = ["sleptim1"], bins = 12, range = bin_range)
# Out:
# array([[<Axes: title={'center': 'sleptim1'}>]], dtype=object)

# %%
print(df['sleptim1'].value_counts())
# Out:
# sleptim1
# 7.0     132927
# 8.0     125442
# 6.0      95880
# 5.0      30122
# 9.0      21210
# 4.0      12433
# 10.0     10459
# 3.0       3260
# 12.0      3004
# 11.0       686
# 16.0       329
# 15.0       317
# 14.0       295
# 13.0       165
# Name: count, dtype: int64

# %%
#cols = ['physhlth', 'menthlth', 'exerany2', 'educa', 'income3', 'weight2', 'height3', 'lcsnumcg', 'avedrnk3', 'lsatisfy', 'mscode', 'x.age80', 'x.bmi5', 'sleptim1']
correlation_coefficients = {}
for col in cols:
    correlation_coefficients[col] = undersampled_df[col].corr(undersampled_df['sleptim1'])
        
print(correlation_coefficients)
        
correlation_coefficients = {}
for col in cols:
    correlation_coefficients[col] = undersampled_df[col].corr(undersampled_df['slptscore'])
        
print(correlation_coefficients)

correlation_coefficients = {}
# Out:
# {'x.state': -0.0022177233824807008, 'sexvar': 0.02066059898884046, 'physhlth': -0.06492741204626354, 'menthlth': -0.15328003029375198, 'exerany2': 0.0002653406550390848, 'cvdinfr4': -0.011193603335613663, 'cvdcrhd4': -0.015695889370563102, 'cvdstrk3': -0.015176139274622356, 'asthma3': 0.06160789027503231, 'asthnow': 0.020630548305860086, 'addepev3': 0.058038829509145476, 'chckdny2': -0.012869340886846164, 'havarth4': 0.01983756562355366, 'diabete4': -0.011573153318290095, 'educa': 0.025562433921586164, 'income3': 0.007179386796549865, 'weight2': -0.006359643173104485, 'height3': 0.016041169191972817, 'lcsnumcg': 0.011167403446911639, 'avedrnk3': -0.060526137476110894, 'lsatisfy': -0.12595103917887032, 'emtsuprt': -0.10617947628991017, 'sdhisolt': 0.09338844053671991, 'mscode': 0.010587802653434755, 'x.age80': 0.15009066898762524, 'x.bmi5': -0.061493518351775245, 'sleptim1': 0.9999999999999999}
# {'x.state': 0.0026096943929512454, 'sexvar': -0.0009144990636041165, 'physhlth': -0.2366852627579537, 'menthlth': -0.27229006728189237, 'exerany2': -0.151871668205693, 'cvdinfr4': 0.06719296821648818, 'cvdcrhd4': 0.04794859918922249, 'cvdstrk3': 0.07207277188074722, 'asthma3': 0.10095886182659071, 'asthnow': 0.06644015673780702, 'addepev3': 0.16668575931112475, 'chckdny2': 0.06018251680045238, 'havarth4': 0.10223795271606337, 'diabete4': 0.07570253258004138, 'educa': 0.15339487781163477, 'income3': 0.1961142844260861, 'weight2': -0.019205789831644997, 'height3': 0.003630770347916498, 'lcsnumcg': -0.03487219897645864, 'avedrnk3': -0.11520188720955998, 'lsatisfy': -0.22781995180869824, 'emtsuprt': -0.1740318442081796, 'sdhisolt': 0.18011337520579826, 'mscode': -0.002642990792500895, 'x.age80': 0.06912435412658405, 'x.bmi5': -0.0987087962492238, 'sleptim1': 0.5076731225101317}

# %%
# ax = undersampled_df.plot.hist(column = ['sleptim1'], by =["income3"], figsize=(10,30), bins =12, range=bin_range)
plt.scatter(undersampled_df['slptscore'], undersampled_df['menthlth'], s=70, alpha=0.03)

# %%
cols = [
        'physhlth', # number of days physical health is not good(per month)
        'menthlth', # number of days mental health is not good(per month)
        'exerany2', # Exercise in Past 30 Days   
        'addepev3', #(Ever told) you had a depressive disorder
        'educa', # eudcation level
        'income3', # income level 
        'weight2', # reported weight in pounds
        'height3', # reported height in feet and inches 
        'lcsnumcg', # how many cigarettes do you smoke each day?
        'avedrnk3', # Avg alcoholic drinks per day in past 30
        'lsatisfy', # satisfaction with life
        'emtsuprt', # How often get emotional support needed
        'sdhisolt', #How often do you feel socially isolated from others?
        'mscode', # Metropolitan Status Code
        'x.age80', # Imputed Age value collapsed above 80
        'x.bmi5', # Computed body mass index 
        'slptscore'# sleep time
       ]

plt.figure(figsize=(15, 15))

data_correl = undersampled_df[cols]
dataplot = sb.heatmap(data_correl.corr(), cmap="YlGnBu", annot=True)
